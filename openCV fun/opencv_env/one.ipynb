# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
# Read image as gray scale.
cb_img = cv2.imread("images.jpg",0)

# Print the image data (pixel values), element of a 2D numpy array.
# Each pixel value is 8-bits [0,255]
print(cb_img)
# Out:
# [[147 148 149 ... 106 106 106]
#  [147 148 149 ... 107 107 106]
#  [148 148 149 ... 107 107 107]
#  ...
#  [ 33  33  33 ...  23  23  23]
#  [ 37  37  36 ...  21  21  21]
#  [ 39  39  39 ...  31  31  31]]

# %%
Image(filename="images.jpg")

# %%
print("image size ",cb_img.shape)
print("Data type of image is ", cb_img.dtype)
# Out:
# image size  (183, 275)
# Data type of image is  uint8

# %%
plt.imshow(cb_img)

# %%
plt.imshow(cb_img, cmap='gray')

# %%
cb_img_color = cv2.imread("images.jpg",1)

# Print the image data (pixel values), element of a 2D numpy array.
# Each pixel value is 8-bits [0,255]
print(cb_img)
# Out:
# [[147 148 149 ... 106 106 106]
#  [147 148 149 ... 107 107 106]
#  [148 148 149 ... 107 107 107]
#  ...
#  [ 33  33  33 ...  23  23  23]
#  [ 37  37  36 ...  21  21  21]
#  [ 39  39  39 ...  31  31  31]]

# %%
plt.imshow(cb_img_color)

# %%
coke_img_channels_reversed = cb_img_color[:, :, ::-1]
plt.imshow(coke_img_channels_reversed)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 coke_img_channels_reversed = cb_img_color[:, :, ::-1]
#       2 plt.imshow(coke_img_channels_reversed)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
coke_img_channels_reversed = cb_img_color[:, ::-1]
plt.imshow(coke_img_channels_reversed)

# %%
img_rgb = cv2.cvtColor(cb_img_color, cv2.COLOR_BGR2RGB)

# Display the image

# %%
plt.imshow(img_rgb)

# %%
img_NZ_bgr = cv2.imread("images.jpg",cv2.IMREAD_COLOR)
b,g,r = cv2.split(img_NZ_bgr)
plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r,cmap='gray');plt.title("Red Channel");
plt.subplot(142);plt.imshow(g,cmap='gray');plt.title("Green Channel");
plt.subplot(143);plt.imshow(b,cmap='gray');plt.title("Blue Channel");

# Merge the individual channels into a BGR image
imgMerged = cv2.merge((b,g,r))
# Show the merged output
plt.subplot(144);plt.imshow(imgMerged[:,:,::-1]);plt.title("Merged Output");
#depends on intensity, so below red intensity is very high so means low content of red in overall picture

# %%
cb_img_copy = cb_img.copy()
cb_img_copy[2,2] = 200
cb_img_copy[2,3] = 200
cb_img_copy[3,2] = 200
cb_img_copy[3,3] = 200

# Same as above
# cb_img_copy[2:3,2:3] = 200

plt.imshow(cb_img_copy, cmap='gray')

# %%
cb_img_copy = cb_img_color.copy()


# Same as above
cb_img_copy[2:10,2:10] = 200

plt.imshow(cb_img_copy, cmap='gray')

# %%
img_NZ_rgb_flipped_horz = cv2.flip(img_NZ_rgb, 1)
img_NZ_rgb_flipped_vert = cv2.flip(img_NZ_rgb, 0)
img_NZ_rgb_flipped_both = cv2.flip(img_NZ_rgb, -1)

# Show the images
plt.figure(figsize=[18,5])
plt.subplot(141);plt.imshow(img_NZ_rgb_flipped_horz);plt.title("Horizontal Flip");
plt.subplot(142);plt.imshow(img_NZ_rgb_flipped_vert);plt.title("Vertical Flip");
plt.subplot(143);plt.imshow(img_NZ_rgb_flipped_both);plt.title("Both Flipped");
plt.subplot(144);plt.imshow(img_NZ_rgb);plt.title("Original");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 img_NZ_rgb_flipped_horz = cv2.flip(img_NZ_rgb, 1)
#       2 img_NZ_rgb_flipped_vert = cv2.flip(img_NZ_rgb, 0)
#       3 img_NZ_rgb_flipped_both = cv2.flip(img_NZ_rgb, -1)
#
# NameError: name 'img_NZ_rgb' is not defined

# %%
img_NZ_rgb_flipped_horz = cv2.flip(img_NZ_bgr, 1)
img_NZ_rgb_flipped_vert = cv2.flip(img_NZ_bgr, 0)
img_NZ_rgb_flipped_both = cv2.flip(img_NZ_bgr, -1)

# Show the images
plt.figure(figsize=[18,5])
plt.subplot(141);plt.imshow(img_NZ_rgb_flipped_horz);plt.title("Horizontal Flip");
plt.subplot(142);plt.imshow(img_NZ_rgb_flipped_vert);plt.title("Vertical Flip");
plt.subplot(143);plt.imshow(img_NZ_rgb_flipped_both);plt.title("Both Flipped");
plt.subplot(144);plt.imshow(img_NZ_bgr);plt.title("Original");

# %%
image1 = cv2.imread("images.jpg", cv2.IMREAD_COLOR)

# %%
imageText = image1.copy()
text = "Washington DC"
fontScale = 1.2
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2

cv2.putText(imageText, text, (100, 100), fontFace, fontScale, fontColor, fontThickness, cv2.LINE_AA);

# Display the image
plt.imshow(imageText[:,:,::-1])
